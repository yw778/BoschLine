# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc
sns.set_style('whitegrid')

# %%
STATIONS = ['S32', 'S33', 'S34']

# %%
train_date_part = pd.read_csv('../../data/train_numeric.csv', nrows=10000)

# %%
train_date_part.head()
# Out:
#    Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# 0   4     0.030    -0.034    -0.197    -0.179     0.118      0.116     -0.015
# 1   6       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   7     0.088     0.086     0.003    -0.052     0.161      0.025     -0.015
# 3   9    -0.036    -0.064     0.294     0.330     0.074      0.161      0.022
# 4  11    -0.055    -0.086     0.294     0.330     0.118      0.025      0.030
#
#    L0_S0_F14  L0_S0_F16    ...     L3_S50_F4245  L3_S50_F4247  L3_S50_F4249  \
# 0     -0.032      0.020    ...              NaN           NaN           NaN
# 1        NaN        NaN    ...              NaN           NaN           NaN
# 2     -0.072     -0.225    ...              NaN           NaN           NaN
# 3      0.128     -0.026    ...              NaN           NaN           NaN
# 4      0.168     -0.169    ...              NaN           NaN           NaN
#
#    L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  L3_S51_F4258  L3_S51_F4260  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    L3_S51_F4262  Response
# 0           NaN         0
# 1           NaN         0
# 2           NaN         0
# 3           NaN         0
# 4           NaN         0
#
# [5 rows x 970 columns]

# %%
# count non-nan value for each columns
date_cols = train_date_part.drop(['Id','Response'], axis=1).count().reset_index().sort_values(by=0, ascending=False)
date_cols
# Out:
#             index     0
# 881  L3_S37_F3948  9473
# 879  L3_S37_F3944  9473
# 882  L3_S37_F3950  9473
# 880  L3_S37_F3946  9473
# 784  L3_S30_F3534  9466
# 842  L3_S30_F3824  9466
# 843  L3_S30_F3829  9466
# 789  L3_S30_F3559  9466
# 822  L3_S30_F3724  9466
# 787  L3_S30_F3549  9466
# 786  L3_S30_F3544  9466
# 785  L3_S30_F3539  9466
# 783  L3_S30_F3529  9466
# 840  L3_S30_F3814  9466
# 782  L3_S30_F3524  9466
# 781  L3_S30_F3519  9466
# 780  L3_S30_F3514  9466
# 779  L3_S30_F3509  9466
# 778  L3_S30_F3504  9466
# 777  L3_S30_F3499  9466
# 776  L3_S30_F3494  9466
# 841  L3_S30_F3819  9466
# 788  L3_S30_F3554  9466
# 839  L3_S30_F3809  9466
# 830  L3_S30_F3764  9466
# 823  L3_S30_F3729  9466
# 824  L3_S30_F3734  9466
# 838  L3_S30_F3804  9466
# 826  L3_S30_F3744  9466
# 827  L3_S30_F3749  9466
# ..            ...   ...
# 509  L1_S25_F2375    19
# 507  L1_S25_F2365    19
# 506  L1_S25_F2356    19
# 505  L1_S25_F2351    19
# 504  L1_S25_F2346    19
# 503  L1_S25_F2341    19
# 502  L1_S25_F2336    19
# 508  L1_S25_F2370    19
# 569  L1_S25_F2584    18
# 557  L1_S25_F2516    18
# 564  L1_S25_F2559    18
# 570  L1_S25_F2589    18
# 568  L1_S25_F2579    18
# 558  L1_S25_F2525    18
# 566  L1_S25_F2569    18
# 565  L1_S25_F2564    18
# 567  L1_S25_F2574    18
# 563  L1_S25_F2554    18
# 562  L1_S25_F2545    18
# 561  L1_S25_F2540    18
# 560  L1_S25_F2535    18
# 559  L1_S25_F2530    18
# 471  L1_S25_F2199     5
# 465  L1_S25_F2181     5
# 470  L1_S25_F2196     5
# 469  L1_S25_F2193     5
# 468  L1_S25_F2190     5
# 467  L1_S25_F2187     5
# 466  L1_S25_F2184     5
# 472  L1_S25_F2202     5
#
# [968 rows x 2 columns]

# %%
date_cols['station'] = date_cols['index'].apply(lambda s: s.split('_')[1])

# %%
date_cols
# Out:
#             index     0 station
# 881  L3_S37_F3948  9473     S37
# 879  L3_S37_F3944  9473     S37
# 882  L3_S37_F3950  9473     S37
# 880  L3_S37_F3946  9473     S37
# 784  L3_S30_F3534  9466     S30
# 842  L3_S30_F3824  9466     S30
# 843  L3_S30_F3829  9466     S30
# 789  L3_S30_F3559  9466     S30
# 822  L3_S30_F3724  9466     S30
# 787  L3_S30_F3549  9466     S30
# 786  L3_S30_F3544  9466     S30
# 785  L3_S30_F3539  9466     S30
# 783  L3_S30_F3529  9466     S30
# 840  L3_S30_F3814  9466     S30
# 782  L3_S30_F3524  9466     S30
# 781  L3_S30_F3519  9466     S30
# 780  L3_S30_F3514  9466     S30
# 779  L3_S30_F3509  9466     S30
# 778  L3_S30_F3504  9466     S30
# 777  L3_S30_F3499  9466     S30
# 776  L3_S30_F3494  9466     S30
# 841  L3_S30_F3819  9466     S30
# 788  L3_S30_F3554  9466     S30
# 839  L3_S30_F3809  9466     S30
# 830  L3_S30_F3764  9466     S30
# 823  L3_S30_F3729  9466     S30
# 824  L3_S30_F3734  9466     S30
# 838  L3_S30_F3804  9466     S30
# 826  L3_S30_F3744  9466     S30
# 827  L3_S30_F3749  9466     S30
# ..            ...   ...     ...
# 509  L1_S25_F2375    19     S25
# 507  L1_S25_F2365    19     S25
# 506  L1_S25_F2356    19     S25
# 505  L1_S25_F2351    19     S25
# 504  L1_S25_F2346    19     S25
# 503  L1_S25_F2341    19     S25
# 502  L1_S25_F2336    19     S25
# 508  L1_S25_F2370    19     S25
# 569  L1_S25_F2584    18     S25
# 557  L1_S25_F2516    18     S25
# 564  L1_S25_F2559    18     S25
# 570  L1_S25_F2589    18     S25
# 568  L1_S25_F2579    18     S25
# 558  L1_S25_F2525    18     S25
# 566  L1_S25_F2569    18     S25
# 565  L1_S25_F2564    18     S25
# 567  L1_S25_F2574    18     S25
# 563  L1_S25_F2554    18     S25
# 562  L1_S25_F2545    18     S25
# 561  L1_S25_F2540    18     S25
# 560  L1_S25_F2535    18     S25
# 559  L1_S25_F2530    18     S25
# 471  L1_S25_F2199     5     S25
# 465  L1_S25_F2181     5     S25
# 470  L1_S25_F2196     5     S25
# 469  L1_S25_F2193     5     S25
# 468  L1_S25_F2190     5     S25
# 467  L1_S25_F2187     5     S25
# 466  L1_S25_F2184     5     S25
# 472  L1_S25_F2202     5     S25
#
# [968 rows x 3 columns]

# %%
date_cols = date_cols[date_cols['station'].isin(STATIONS)]

# %%
date_cols
# Out:
#             index     0 station
# 862  L3_S34_F3882  9436     S34
# 861  L3_S34_F3880  9436     S34
# 860  L3_S34_F3878  9436     S34
# 859  L3_S34_F3876  9436     S34
# 852  L3_S33_F3861  9433     S33
# 855  L3_S33_F3867  9433     S33
# 858  L3_S33_F3873  9433     S33
# 857  L3_S33_F3871  9433     S33
# 856  L3_S33_F3869  9433     S33
# 853  L3_S33_F3863  9433     S33
# 854  L3_S33_F3865  9433     S33
# 851  L3_S33_F3859  9433     S33
# 849  L3_S33_F3855  9433     S33
# 850  L3_S33_F3857  9433     S33
# 848  L3_S32_F3850   178     S32

# %%
date_cols = date_cols.drop_duplicates('station', keep='first')['index'].tolist()

# %%
date_cols
# Out:
# ['L3_S34_F3882', 'L3_S33_F3861', 'L3_S32_F3850']

# %%
train_date = pd.read_csv('../../data/train_numeric.csv', usecols=['Id'] + date_cols)

# %%
train_date
# Out:
#               Id  L3_S32_F3850  L3_S33_F3861  L3_S34_F3882
# 0              4           NaN        -0.119           0.0
# 1              6           NaN        -0.029           0.0
# 2              7           NaN         0.199           0.0
# 3              9           NaN         0.017           0.0
# 4             11           NaN        -0.074           0.0
# 5             13           NaN         0.017           0.0
# 6             14           NaN         0.017           0.0
# 7             16           NaN        -0.210           0.0
# 8             18           NaN         0.017           0.0
# 9             23           NaN         0.153           0.0
# 10            26           NaN         0.199           0.0
# 11            27           NaN         0.017           0.0
# 12            28           NaN         0.153           0.0
# 13            31           NaN         0.017           0.0
# 14            34           NaN         0.153           0.0
# 15            38           NaN        -0.256           0.0
# 16            41           NaN        -0.074           0.0
# 17            44           NaN         0.062           0.0
# 18            47           NaN         0.062           0.0
# 19            49           NaN        -0.029           0.0
# 20            52           NaN         0.017           0.0
# 21            55           NaN        -0.029           0.0
# 22            56           NaN        -0.029           0.0
# 23            57           NaN         0.017           0.0
# 24            63           NaN        -0.029           0.0
# 25            68           NaN        -0.029           0.0
# 26            70           NaN           NaN           NaN
# 27            71           NaN         0.108           0.0
# 28            72           NaN        -0.074           0.0
# 29            73           NaN         0.108           0.0
# ...          ...           ...           ...           ...
# 1183717  2367437           NaN         0.017           0.0
# 1183718  2367439           NaN        -0.074           0.0
# 1183719  2367440           NaN        -0.074           0.0
# 1183720  2367442           NaN         0.108           0.0
# 1183721  2367443           NaN        -0.029           0.0
# 1183722  2367444           NaN        -0.165           0.0
# 1183723  2367452           NaN         0.153           0.0
# 1183724  2367458           NaN         0.017           0.0
# 1183725  2367459           NaN         0.153           0.0
# 1183726  2367460           NaN         0.108           0.0
# 1183727  2367461           NaN        -0.074           0.0
# 1183728  2367462           NaN         0.017           0.0
# 1183729  2367464           NaN         0.017           0.0
# 1183730  2367466           NaN        -0.119           0.0
# 1183731  2367469           NaN        -0.029           0.0
# 1183732  2367471           NaN        -0.074           0.0
# 1183733  2367472           NaN        -0.165           0.0
# 1183734  2367473           NaN        -0.119           0.0
# 1183735  2367474           NaN        -0.165           0.0
# 1183736  2367476           NaN        -0.074           0.0
# 1183737  2367478           NaN        -0.119           0.0
# 1183738  2367480           NaN        -0.029           0.0
# 1183739  2367484           NaN         0.017           0.0
# 1183740  2367487           NaN         0.199           0.0
# 1183741  2367488           NaN         0.062           0.0
# 1183742  2367490           NaN        -0.119           0.0
# 1183743  2367491           NaN        -0.210           0.0
# 1183744  2367492         0.043         0.017           0.0
# 1183745  2367493           NaN         0.062           0.0
# 1183746  2367495           NaN        -0.029           0.0
#
# [1183747 rows x 4 columns]

# %%
train_date.columns = ['Id'] + STATIONS

# %%
for station in STATIONS:
    train_date[station] = 1 * (train_date[station] >= 0)

# %%
response = pd.read_csv('../../data/train_numeric.csv', usecols=['Id', 'Response'])

# %%
train = response.merge(train_date, how='left', on='Id')

# %%
train
# Out:
#               Id  Response  S32  S33  S34
# 0              4         0    0    0    1
# 1              6         0    0    0    1
# 2              7         0    0    1    1
# 3              9         0    0    1    1
# 4             11         0    0    0    1
# 5             13         0    0    1    1
# 6             14         0    0    1    1
# 7             16         0    0    0    1
# 8             18         0    0    1    1
# 9             23         0    0    1    1
# 10            26         0    0    1    1
# 11            27         0    0    1    1
# 12            28         0    0    1    1
# 13            31         0    0    1    1
# 14            34         0    0    1    1
# 15            38         0    0    0    1
# 16            41         0    0    0    1
# 17            44         0    0    1    1
# 18            47         0    0    1    1
# 19            49         0    0    0    1
# 20            52         0    0    1    1
# 21            55         0    0    0    1
# 22            56         0    0    0    1
# 23            57         0    0    1    1
# 24            63         0    0    0    1
# 25            68         0    0    0    1
# 26            70         0    0    0    0
# 27            71         0    0    1    1
# 28            72         0    0    0    1
# 29            73         0    0    1    1
# ...          ...       ...  ...  ...  ...
# 1183717  2367437         0    0    1    1
# 1183718  2367439         0    0    0    1
# 1183719  2367440         0    0    0    1
# 1183720  2367442         0    0    1    1
# 1183721  2367443         0    0    0    1
# 1183722  2367444         0    0    0    1
# 1183723  2367452         0    0    1    1
# 1183724  2367458         0    0    1    1
# 1183725  2367459         0    0    1    1
# 1183726  2367460         0    0    1    1
# 1183727  2367461         0    0    0    1
# 1183728  2367462         0    0    1    1
# 1183729  2367464         0    0    1    1
# 1183730  2367466         0    0    0    1
# 1183731  2367469         0    0    0    1
# 1183732  2367471         0    0    0    1
# 1183733  2367472         0    0    0    1
# 1183734  2367473         0    0    0    1
# 1183735  2367474         0    0    0    1
# 1183736  2367476         0    0    0    1
# 1183737  2367478         0    0    0    1
# 1183738  2367480         0    0    0    1
# 1183739  2367484         0    0    1    1
# 1183740  2367487         0    0    1    1
# 1183741  2367488         0    0    1    1
# 1183742  2367490         0    0    0    1
# 1183743  2367491         0    0    0    1
# 1183744  2367492         0    1    1    1
# 1183745  2367493         0    0    1    1
# 1183746  2367495         0    0    0    1
#
# [1183747 rows x 5 columns]

# %%
train['cnt'] = 1

# %%
failure_rate = train.groupby(STATIONS).sum()[['Response', 'cnt']]

# %%
failure_rate
# Out:
#              Response     cnt
# S32 S33 S34
# 0   0   0         749   65490
#         1        2807  536094
#     1   0           4     819
#         1        2784  568765
# 1   0   0         408    2317
#         1         101    6316
#     1   0           0       3
#         1          26    3943

# %%
failure_rate['failure_rate'] = failure_rate['Response'] / failure_rate['cnt']

# %%
failure_rate = failure_rate[failure_rate['cnt'] > 1000]  # remove

# %%
failure_rate.head(20)
# Out:
#              Response     cnt  failure_rate
# S32 S33 S34
# 0   0   0         749   65490      0.011437
#         1        2807  536094      0.005236
#     1   1        2784  568765      0.004895
# 1   0   0         408    2317      0.176090
#         1         101    6316      0.015991
#     1   1          26    3943      0.006594

# %%
failure_rate_pretty = failure_rate.reset_index()

# %%
failure_rate_pretty
# Out:
#    S32  S33  S34  Response     cnt  failure_rate
# 0    0    0    0       749   65490      0.011437
# 1    0    0    1      2807  536094      0.005236
# 2    0    1    1      2784  568765      0.004895
# 3    1    0    0       408    2317      0.176090
# 4    1    0    1       101    6316      0.015991
# 5    1    1    1        26    3943      0.006594

# %%
failure_rate_pretty['group'] = [[s if row[s] else '' for s in STATIONS] 
                         for _, row in failure_rate_pretty.iterrows()]

# %%
failure_rate_pretty
# Out:
#    S32  S33  S34  Response     cnt  failure_rate            group
# 0    0    0    0       749   65490      0.011437           [, , ]
# 1    0    0    1      2807  536094      0.005236        [, , S34]
# 2    0    1    1      2784  568765      0.004895     [, S33, S34]
# 3    1    0    0       408    2317      0.176090        [S32, , ]
# 4    1    0    1       101    6316      0.015991     [S32, , S34]
# 5    1    1    1        26    3943      0.006594  [S32, S33, S34]

# %%
failure_rate_pretty = failure_rate.reset_index()
failure_rate_pretty['group'] = ['-'.join([s if row[s] else '' for s in STATIONS]) \
                         for _, row in failure_rate_pretty.iterrows()]
fig=plt.figure(figsize=(10, 4))
sns.barplot(x='group', y="failure_rate", data=failure_rate_pretty, color='r', alpha=0.8)
plt.ylabel('failure rate')
for i, row in failure_rate_pretty.iterrows():
    plt.text(i, row['failure_rate']+0.01, np.round(row['failure_rate'], 3),
             verticalalignment='top', horizontalalignment='center')
plt.title('Station combinations %s' % str(STATIONS))
fig.savefig('failure_rate.png', dpi=300)
plt.show()
